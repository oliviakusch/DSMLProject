# %%
import pandas as pd
import numpy as np

# %%
# read in data
interactions = pd.read_csv('interactions_train.csv')
items = pd.read_csv('items.csv')

# %%
print(interactions.columns)
# what is u, i, t?
# user, items, time (?) 

print(interactions.head())

# to see what this is about
print('users:', interactions['u'].nunique())
print('items referenced:', interactions['i'].nunique())
print('items rows:', items.shape[0])
# Out:
# Index(['u', 'i', 't'], dtype='object')
#       u      i             t
# 0  4456   8581  1.687541e+09
# 1   142   1964  1.679585e+09
# 2   362   3705  1.706872e+09
# 3  1809  11317  1.673533e+09
# 4  4384   1323  1.681402e+09
# users: 7838
# items referenced: 15109
# items rows: 15291

# %%
print('rows, cols:')
print(items.shape)

print('Column names:')
print(items.columns)

print(items.head(2))

print('Null counts per column:')
print(items.isnull().sum().sort_values(ascending=False))
# Out:
# rows, cols:
# (15291, 6)
# Column names
# Index(['Title', 'Author', 'ISBN Valid', 'Publisher', 'Subjects', 'i'], dtype='object')
#                                                Title  \
# 0  Classification décimale universelle : édition ...
# 1  Les interactions dans l'enseignement des langu...
#
#                      Author                 ISBN Valid    Publisher  \
# 0                       NaN  9782871303336; 2871303339  Ed du CEFAL
# 1  Cicurel, Francine, 1947-  9782278058327; 2278058320       Didier
#
#                                             Subjects  i
# 0  Classification décimale universelle; Indexatio...  0
# 1  didactique--langue étrangère - enseignement; d...  1
# Null counts per column:
# Author        2653
# Subjects      2223
# ISBN Valid     723
# Publisher       25
# Title            0
# i                0
# dtype: int64

# %% [markdown]
# #### Title
# - Title of media
# - No nulls, messy contents
#
# #### Author
# - Author of media
# - 2.6k nulls
#
# #### ISBN Valid
#
# #### Publisher
#
# #### Subjects
#
# #### i
